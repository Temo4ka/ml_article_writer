# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

work_dir = "/content/dataset"
os.makedirs(work_dir, exist_ok=True)

# %%
zip_paths = [
    "/content/drive/MyDrive/Конкурс И себе и людям 2.zip",
    "/content/drive/MyDrive/Корпоративный кодекс.zip",
    "/content/drive/MyDrive/Взаимодействие с Уч. заведениями.zip",
]

# %%
import zipfile
import shutil

extract_dir = os.path.join(work_dir, "extracted")
os.makedirs(extract_dir, exist_ok=True)

for zip_path in zip_paths:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

# %%
# !pip install python-docx

# %%
# !pip install chardet

# %%
import glob
from docx import Document
import chardet

articles = []
docx_files = glob.glob(os.path.join(extract_dir, "**", "*.docx"), recursive=True)

for file_path in docx_files:
    try:
        doc = Document(file_path)
        full_text = "\n".join([para.text for para in doc.paragraphs if para.text.strip()])
        articles.append(full_text)

    except Exception as e:
        print(e)

len(articles)
# Out:
# Package not found at '/content/dataset/extracted/Корпоративный кодекс/~$мы постов Кодекс этики на ноябрь.docx'
# 29

# %%
# import json

dataset_path = os.path.join(work_dir, "dataset.jsonl")

# with open(dataset_path, "w", encoding="utf-8") as out:
#     for text in articles:
#         entry = {
#             "messages": [
#                 {"role": "system", "content": ""},
#                 {"role": "user", "content": ""},
#                 {"role": "assistant", "content": text}
#             ]
#         }
#         out.write(json.dumps(entry, ensure_ascii=False) + "\n")

# %%
#!pip uninstall torch torchvision torchaudio -y

# версии совместимые с коллабом
#!pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124

#!pip install unsloth -q
#!pip install unsloth-zoo -q
# Out:
# Found existing installation: torch 2.10.0
# Uninstalling torch-2.10.0:
#   Successfully uninstalled torch-2.10.0
# Found existing installation: torchvision 0.25.0
# Uninstalling torchvision-0.25.0:
#   Successfully uninstalled torchvision-0.25.0
# Found existing installation: torchaudio 2.9.0+cu128
# Uninstalling torchaudio-2.9.0+cu128:
#   Successfully uninstalled torchaudio-2.9.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 886.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 62.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 68.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.8 MB/s eta 0:00:00
# ...

# %%
# !pip install unsloth[colab-new] -q
# Out:
# WARNING: unsloth 2026.2.1 does not provide the extra 'triton'

# %%
import torch
from unsloth import FastLanguageModel

model_name = "unsloth/Qwen3-4B"
max_seq_length = 2048

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# ...

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=32,
    lora_alpha=64,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    use_gradient_checkpointing="unsloth"
)
# Out:
# Unsloth 2026.2.1 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files=dataset_path, split="train")

def format_chat(example):
    text = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False,
    )

    return {"text": text}

dataset = dataset.map(format_chat)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/29 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    args=SFTConfig(
        output_dir="./qwen3-style-output",
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        num_train_epochs=3,
        learning_rate=2e-4,
        logging_steps=10,
        save_steps=50,
        optim="adamw_8bit",
        warmup_steps=5,
        lr_scheduler_type="linear",
        report_to="none",
        max_seq_length=max_seq_length,
        dataset_text_field="text",
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/29 [00:00<?, ? examples/s]
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 29 | Num Epochs = 3 | Total steps = 12
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 66,060,288 of 4,088,528,384 (1.62% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='7' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7/12 01:01 < 01:01, 0.08 it/s, Epoch 1.53/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 02:15, Epoch 3/3]
#     </div>
# ...

# %%
model.save_pretrained("qwen3-style-lora")
tokenizer.save_pretrained("qwen3-style-lora")

merged_model = model.merge_and_unload()
merged_model.save_pretrained("qwen3-style-merged")
tokenizer.save_pretrained("qwen3-style-merged")
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/tuners/lora/bnb.py:397: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# ('qwen3-style-merged/tokenizer_config.json',
#  'qwen3-style-merged/special_tokens_map.json',
#  'qwen3-style-merged/chat_template.jinja',
#  'qwen3-style-merged/vocab.json',
#  'qwen3-style-merged/merges.txt',
#  'qwen3-style-merged/added_tokens.json',
#  'qwen3-style-merged/tokenizer.json')

# %%
# !mkdir -p /content/drive/MyDrive/qwen3-style-model
# !cp -r qwen3-style-lora/* /content/drive/MyDrive/qwen3-style-model/

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

from unsloth import FastLanguageModel

model, tokenizer = FastLanguageModel.from_pretrained(
    "qwen3-style-lora",
    max_seq_length=2048,
    load_in_4bit=True,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2026.2.1 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
def generate_article(theme):
    messages = [
        {"role": "system", "content": "Ты - опытный автор, который пишет статьи в стиле, максимально похожем на предоставленные примеры."},
        {"role": "user", "content": f"Напиши статью на тему: {theme} в твоём фирменном стиле. Не добавляй имя автора."},
    ]
    text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = tokenizer([text], return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=1024, temperature=0.7, top_p=0.9, repetition_penalty=1.05)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
print(generate_article("будущее нейросетей в 2026 году"))
# Out:
# system
# Ты - опытный автор, который пишет статьи в стиле, максимально похожем на предоставленные примеры
# user
# Напиши статью на тему: будущее нейросетей в 2026 году в твоём фирменном стиле
# assistant
# <think>
# </think>
#
#
#
# Вот статья.
#
# Артём Сорокин
# Мы уже давно говорили о том, что в 2024 году нейросети стали не просто инструментом, а полноценной частью нашей жизни и бизнеса. Но в 2026 году всё ещё глубже и быстрее начнёт проникать в наш мир. Поговорим о том, какие перспективы открывает нам развитие искусственного интеллекта именно в следующем году.
# ...
